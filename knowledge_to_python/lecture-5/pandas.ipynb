# %%
import pandas as pd

# %%
# читаем
df = pd.read_csv('./california_housing_train.csv')

# %%
# первые 10 элементов файла
df.head(n = 10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
# последние 10 элементов файла
df.tail(n = 10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16990      1530.0       653.0         1.7038             78300.0
# ...

# %%
# размеры таблицы с данными
df.shape
# Out:
# (17000, 9)

# %%
# проверка есть ли "нулевые" данные в таблице
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
# проверка есть ли "нулевые" данные в таблице с помощью sum()
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
# тип данных столбца
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
# получение всех столбцов
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
# выборка данных одного столбца
df['longitude']
# Out:
# 0        1015.0
# 1        1129.0
# 2         333.0
# 3         515.0
# 4         624.0
#           ...
# 16995     907.0
# 16996    1194.0
# 16997    1244.0
# 16998    1298.0
# 16999     806.0
# Name: population, Length: 17000, dtype: float64

# %%
df[['longitude', 'population']]
# Out:
#        longitude  population
# 0        -114.31      1015.0
# 1        -114.47      1129.0
# 2        -114.56       333.0
# 3        -114.57       515.0
# 4        -114.57       624.0
# ...          ...         ...
# 16995    -124.26       907.0
# 16996    -124.27      1194.0
# 16997    -124.30      1244.0
# 16998    -124.30      1298.0
# 16999    -124.35       806.0
#
# [17000 rows x 2 columns]

# %%
# Необходимо вывести строки таблицы, у которых медианный возраст здания (housing_median_age) меньше 20
df[df['housing_median_age'] < 20]

# %%
# Необходимо вывести total_rooms, у которого медианный возраст здания (housing_median_age) меньше 20
df[df['housing_median_age'] < 20]['total_rooms']
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 10       3741.0
#           ...
# 16983    3140.0
# 16987    3461.0
# 16991    3159.0
# 16997    2677.0
# 16998    2672.0
# Name: total_rooms, Length: 4826, dtype: float64

# %%
# простая статистика
print(df['population'].max()) # максимальное значение столбца
# Out:
# 35682.0

# %%
print(df['population'].min()) # - минимальное
# Out:
# 3.0

# %%
print(df['population'].mean()) # - среднее
# Out:
# 1429.5739411764705

# %%
print(df['population'].sum()) # - сумма
# Out:
# 24302757.0

# %%
print(df['population'].median()) # - медианное значение
# Out:
# 1167.0

# %%
df.describe() # - общая информация по всем данным
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...
